# %% [markdown]
# <a href="https://colab.research.google.com/github/Matancoo/Advance-NLP/blob/main/ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GPU
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue May 23 08:39:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Github Access TODO: learn howe to do this
# %cd /content/drive/MyDrive/Github/Advance-NLP
git_token = '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'
username = 'Matancoo'
repository = 'Advance-NLP'
# !git clone https://{git_token}@github.com/{username}/{repository}
# %cd {repository}
# %ls -a
# !git status 
# !git add /content/drive/MyDrive/Github/Advance-NLP/exercise_1
# !git status
# !git config user.email "matanco0079@gmail.com"
# !git commit -m 'updated the requirements file' 
# ! git remote -v
# !git remote set-url origin https://{git_token}:x-oauth-basic@github.com/{username}/{repository}
# !git push
# Out:
# /content/drive/MyDrive/Github/Advance-NLP

# %%
# Install relevant packages
# !python -m pip install -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: aiohttp==3.8.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 1)) (3.8.3)
# Requirement already satisfied: aiosignal==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: async-timeout==4.0.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 4)) (4.0.2)
# Requirement already satisfied: attrs==22.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: autopep8==2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==2.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: click==8.1.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 9)) (8.1.3)
# Requirement already satisfied: datasets==2.12.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 10)) (2.12.0)
# Requirement already satisfied: dill==0.3.5.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 11)) (0.3.5.1)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: evaluate==0.4.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 13)) (0.4.0)
# Requirement already satisfied: filelock==3.8.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 14)) (3.8.0)
# Requirement already satisfied: frozenlist==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: fsspec==2022.10.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 16)) (2022.10.0)
# Requirement already satisfied: gitdb==4.0.10 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 17)) (4.0.10)
# Requirement already satisfied: GitPython==3.1.31 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 18)) (3.1.31)
# Requirement already satisfied: html5lib==1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 19)) (1.1)
# Requirement already satisfied: huggingface-hub==0.13.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 20)) (0.13.4)
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 21)) (3.4)
# Requirement already satisfied: Jinja2==3.1.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 22)) (3.1.2)
# Requirement already satisfied: MarkupSafe==2.1.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 23)) (2.1.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: multidict==6.0.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 25)) (6.0.2)
# Requirement already satisfied: multiprocess==0.70.13 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 26)) (0.70.13)
# Requirement already satisfied: networkx==3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 27)) (3.0)
# Requirement already satisfied: numpy==1.24.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 28)) (1.24.1)
# Requirement already satisfied: packaging==21.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 29)) (21.3)
# Requirement already satisfied: pandas==1.5.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 30)) (1.5.2)
# Requirement already satisfied: pathtools==0.1.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 31)) (0.1.2)
# Requirement already satisfied: protobuf==4.23.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 32)) (4.23.1)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 33)) (5.9.5)
# Requirement already satisfied: pyarrow==10.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 34)) (10.0.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 35)) (2.8.2)
# Requirement already satisfied: pytz==2022.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 36)) (2022.7)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 37)) (6.0)
# Requirement already satisfied: Pillow==9.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 38)) (9.0.0)
# Requirement already satisfied: regex==2022.10.31 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 39)) (2022.10.31)
# Requirement already satisfied: requests==2.28.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 40)) (2.28.1)
# Requirement already satisfied: responses==0.18.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 41)) (0.18.0)
# Requirement already satisfied: sentry-sdk==1.23.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 42)) (1.23.1)
# Requirement already satisfied: setproctitle==1.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 43)) (1.3.2)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap==5.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 45)) (5.0.0)
# Requirement already satisfied: sympy==1.11.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 46)) (1.11.1)
# Requirement already satisfied: tokenizers==0.13.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 47)) (0.13.3)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (2.0.0)
# Requirement already satisfied: tqdm==4.64.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 49)) (4.64.1)
# Requirement already satisfied: transformers==4.28.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 50)) (4.28.1)
# Requirement already satisfied: typing_extensions==4.4.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 51)) (4.4.0)
# Requirement already satisfied: urllib3==1.26.13 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 52)) (1.26.13)
# Requirement already satisfied: wandb==0.15.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 53)) (0.15.3)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 54)) (0.5.1)
# Requirement already satisfied: xxhash==3.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 55)) (3.1.0)
# Requirement already satisfied: yarl==1.8.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 56)) (1.8.1)
# Requirement already satisfied: pycodestyle>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from autopep8==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging==21.3->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 29)) (3.0.9)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.15.3->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 53)) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->-r /content/drive/MyDrive/Github/Advance-NLP/Advance-NLP/exercise_1/requirements.txt (line 48)) (16.0.5)

# %%
# Imports

import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import DataCollatorWithPadding, AutoModel
from transformers import Trainer, TrainingArguments
from datasets import load_dataset
import evaluate
import sys
import argparse
import random
import wandb

# %%
# wandb login : key = 69bcf5b64357915bea6ac2074e25b69cea6f50e9
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# Helper Functions
def tokenize_function(example,tokenizer):
    return tokenizer(example['sentence'], truncation=True,)  # NOTE: No fixed padding


def compute_metrics(eval_preds:tuple):
    """
    :param eval_preds: logits outputed by the model
    :return: Accuracy -choice metric in SST2
    """
    metric = evaluate.load('glue', 'sst2')
    logits, labels = eval_preds
    preds = np.argmax(logits, axis=-1)
    return metric.compute(predictions=preds, references=labels)

# %%
# # Training parameters required for training
# seed = 3
# training_count = -1
# validation_count = -1
# prediction_count = -1
# SEEDS: list = list(range(seed))

# %%
def train_model(seed:int,checkpoint:str,output_dir:str,tokenized_dataset,data_collator,tokenizer):

    # Weights & Biases Init:
    run = wandb.init(
        settings=wandb.Settings(start_method="fork"),
        project="ANLP_ex1",
        name=checkpoint + "-Seed_number" + str(seed),
        tags=[checkpoint,str(seed),"fine_tuning"],
        notes = "this is a train_run with model: " + checkpoint + " and seed number" + str(seed),
        job_type='train'
    )
    model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)
    training_args = TrainingArguments(
        evaluation_strategy='no', # no evaluation during training,
        seed=seed,
        report_to = 'wandb',
        output_dir = output_dir,
        save_total_limit = 1 # Only keep the most recent checkpoint
    )  # all rest default
# NOTE: somewhy save_total_limit = 1 doesnt work on GoogleDrive
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset['train'],
        eval_dataset=tokenized_dataset['validation'],
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,)
    trainer.train()
    run.finish()
    return trainer

# %%
# Checkpoints for each model in Huggingface: bert/roberta/electra
model1_checkpoint = 'bert-base-uncased'
model2_checkpoint = 'roberta-base'
model3_checkpoint = 'google/electra-base-generator'
checkpoint = model1_checkpoint
seed = 1
output_dir: str = '/content/drive/MyDrive/Github/Advance-NLP/exercise_1/models/'+ checkpoint + str(seed)#TODO: set output_dir in collab to drive

# Pre-processing
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
raw_dataset = load_dataset('sst2')  # Standford Sentiment Treebank
tokenized_dataset = raw_dataset.map(tokenize_function,fn_kwargs={'tokenizer':tokenizer}, batched=True)
# train_dataset = tokenized_dataset['train'] if training_count == -1 else dataset['train'].select(range(training_count))
# validation_dataset = tokenized_dataset['validation'] if validation_count == -1 else dataset['validation'].select(range(validation_count))
# Out:
# Downloading builder script:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.85k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/5.10k [00:00<?, ?B/s]
# Downloading and preparing dataset sst2/default to /root/.cache/huggingface/datasets/sst2/default/2.0.0/9896208a8d85db057ac50c72282bcb8fe755accc671a57dd8059d4e130961ed5...
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Dataset sst2 downloaded and prepared to /root/.cache/huggingface/datasets/sst2/default/2.0.0/9896208a8d85db057ac50c72282bcb8fe755accc671a57dd8059d4e130961ed5. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Map:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Map:   0%|          | 0/872 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1821 [00:00<?, ? examples/s]

# %%
# we will run the following code for each model
trainer = train_model(seed,checkpoint,output_dir,tokenized_dataset,data_collator,tokenizer)
# Out:
# Finishing last run (ID:s0pprn53) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁</td></tr><tr><td>train/global_step</td><td>▁</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>0.06</td></tr><tr><td>train/global_step</td><td>500</td></tr><tr><td>train/learning_rate</td><td>5e-05</td></tr><tr><td>train/loss</td><td>0.444</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bert-base-uncased-Seed_number1</strong> at: <a href='https://wandb.ai/matco/ANLP_ex1/runs/s0pprn53' target="_blank">https://wandb.ai/matco/ANLP_ex1/runs/s0pprn53</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230523_154340-s0pprn53/logs</code>
# Successfully finished last run (ID:s0pprn53). Initializing new run:<br/>
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/content/drive/MyDrive/Github/Advance-NLP/wandb/run-20230523_154527-z15qtn3x</code>
# Syncing run <strong><a href='https://wandb.ai/matco/ANLP_ex1/runs/z15qtn3x' target="_blank">bert-base-uncased-Seed_number1</a></strong> to <a href='https://wandb.ai/matco/ANLP_ex1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/matco/ANLP_ex1' target="_blank">https://wandb.ai/matco/ANLP_ex1</a>
#  View run at <a href='https://wandb.ai/matco/ANLP_ex1/runs/z15qtn3x' target="_blank">https://wandb.ai/matco/ANLP_ex1/runs/z15qtn3x</a>
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='8507' max='25257' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 8507/25257 13:35 < 26:46, 10.43 it/s, Epoch 1.01/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.458300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.362000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.374800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.348400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.344000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.319600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.299400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.322100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.300100</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.321500</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.297400</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.296400</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.283300</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.292100</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.261200</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.264500</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.248400</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# load champion model bnert-uncased with seed 2

model_dir = '/content/drive/MyDrive/Github/Advance-NLP/exercise_1/models/bert-base-uncased2/checkpoint-25000/'


# Evaluation
checkpoint = 'bert-base-uncased'
test_dataset = load_dataset('glue', 'sst2', split='test')
model_dir = '/Users/matancohen/Downloads/checkpoint-25000'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
classification_pipeline = pipeline("text-classification", model=model_dir, tokenizer=tokenizer)
test_sentences = test_dataset['sentence']
test_labels = test_dataset['label']
predictions = classification_pipeline(test_sentences)
predicted_labels = [prediction['label'] for prediction in predictions]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-2a953e4d7df7> in <cell line: 20>()
#      18 )
#      19
# ---> 20 trainer = Trainer(
#      21     model=model,
#      22     args=training_args,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in __init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     333         self.args = args
#     334         # Seed must be set before instantiating the model when using model
# --> 335         enable_full_determinism(self.args.seed) if self.args.full_determinism else set_seed(self.args.seed)
#     336         self.hp_name = None
#     337         self.deepspeed = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer_utils.py in set_seed(seed)
#      91     np.random.seed(seed)
#      92     if is_torch_available():
# ---> 93         torch.manual_seed(seed)
#      94         torch.cuda.manual_seed_all(seed)
#      95         # ^^ safe to call this function even if cuda is not available
#
# /usr/local/lib/python3.10/dist-packages/torch/random.py in manual_seed(seed)
#      38
#      39     if not torch.cuda._is_in_bad_fork():
# ---> 40         torch.cuda.manual_seed_all(seed)
#      41
#      42     import torch.mps
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/random.py in manual_seed_all(seed)
#     111             default_generator.manual_seed(seed)
#     112
# --> 113     _lazy_call(cb, seed_all=True)
#     114
#     115
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in _lazy_call(callable, **kwargs)
#     181 def _lazy_call(callable, **kwargs):
#     182     if is_initialized():
# --> 183         callable()
#     184     else:
#     185         # TODO(torch_deploy): this accesses linecache, which attempts to read the
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/random.py in cb()
#     109         for i in range(device_count()):
#     110             default_generator = torch.cuda.default_generators[i]
# --> 111             default_generator.manual_seed(seed)
#     112
#     113     _lazy_call(cb, seed_all=True)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
roberta = [0.5092,0.8624,0.5092]
electra = [0.8991,0.9025,0.8968]
bert = [0.9094,--,0.9128]

# %%
# Evaluation
metrics = trainer.evaluate(test_dataset)
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-178c61e93cfc> in <cell line: 3>()
#       1 # test_dataset.features
#       2
# ----> 3 predictions = trainer.predict(test_dataset)
#       4 # predictions
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in predict(self, test_dataset, ignore_keys, metric_key_prefix)
#    3067
#    3068         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3069         output = eval_loop(
#    3070             test_dataloader, description="Prediction", ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix
#    3071         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3195                 )
#    3196             if logits is not None:
# -> 3197                 logits = self._pad_across_processes(logits)
#    3198                 logits = self._nested_gather(logits)
#    3199                 if self.preprocess_logits_for_metrics is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _pad_across_processes(self, tensor, pad_index)
#    3333             return tensor
#    3334         # Gather all sizes
# -> 3335         size = torch.tensor(tensor.shape, device=tensor.device)[None]
#    3336         sizes = self._nested_gather(size).cpu()
#    3337
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
